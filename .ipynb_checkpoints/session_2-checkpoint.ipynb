# %%
import os
os.getcwd()
# get current working directory
# Out:
# 'C:\\Users\\pratikchalakh\\Documents\\NareshIT\\Python Session'

# %%
# checkpoit-1:
# empty square bracket before the code cell
# indicste we did nor run the cell

# checkpoint-2
# if we see a + mark inside square bracket
# do not run the nor run the cell

# %% [markdown]
# **github session**

# %%
number2=100

# %%
number2
# Out:
# 100

# %%
  name="pratik"

# %%
name
# Out:
# 'pratik'

# %% [markdown]
# hello today i am learning python
# square bracket is there : yes
# code mode is there : yes
# if these two are there which indicates this current cell used for to write code only
# if you write english i will throw error
# go to top code mode after a drop down symbol is there
# click on that
# we can use see markdown option
# slect it then we can not see any square bracket

# %%
# python

# %% [markdown]
# - esc+m will change mode to markdown mode
# - esc+y will change mode to code mode
# - shift+enter

# %% [markdown]
# # python
# ## python
# ### python
# #### python

# %% [markdown]
# - Hi pratik
# - how are you
# - how do you do

# %% [markdown]
# **now i will show how to upload image**
# - but this will works for only some people
# - dont worry

# %% [markdown]
# <g-img style="max-height:225px;max-width:225px" class="mNsIhb"><img id="dimg_hNh0Z8C8F7ygseMP2OeQ6QI_305" src="data:image/png;base64,..." class="YQ4gaf" height="225" style="object-position:50% 46%" width="225" alt="What is Python Coding? | Juni Learning" data-csiid="hNh0Z8C8F7ygseMP2OeQ6QI_53" data-atf="4"></g-img>
