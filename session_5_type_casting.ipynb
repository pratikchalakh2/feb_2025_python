# %% [markdown]
# ## Type casting
#
# - convrt one data type to another data type
# - we learned 4 data types
#
# -  integer: int
# -  float: float
# -  boolean: bool
# -  string: str

# %% [markdown]
# **int to other data types**

# %%
number=100
type(number)
# Out:
# int

# %%
float_number=float(number)
type(float_number)
# Out:
# float

# %%
bool_number=bool(number)
type(bool_number)
# Out:
# bool

# %%
float_number=float(number)
type(float_number)

# %%
float(100),bool(100),str(100)
# Out:
# (100.0, True, '100')

# %%
print(float(100) )
print(bool(100) )
print(str(100) )
# Out:
# 100.0
# True
# 100

# %%
print(float(-100) )
print(bool(-100) )
print(str(-100) )
# Out:
# -100.0
# True
# -100

# %%
print(float(-100) )
print(bool(0) )
print(str(-100) )
# Out:
# -100.0
# False
# -100

# %% [markdown]
# - zero means off
# - false means off

# %%
print(float(0) )
print(bool(0) )
print(str(0) )
# Out:
# 0.0
# False
# 0

# %% [markdown]
# **float to other data type**

# %%
number=100.5
int(number)
# Out:
# 100

# %%
bool(number)
# Out:
# True

# %%
str(number)
# Out:
# '100.5'

# %%
n1=int(100.5)
n2=bool(100.5)
n3=str(100.5)
print(n1)
print(n2)
print(n3)
# Out:
# 100
# True
# 100.5

# %%
n1=int(0.0)
n2=bool(0.0)
n3=str(0.0)
print(n1)
print(n2)
print(n3)
# Out:
# 0
# False
# 0.0

# %% [markdown]
# **string to other data type**

# %%
int('appple')  # fail
float('apple')  #fail
bool('apple')  #
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int('appple')  # fail
#       2 float('apple')  #fail
#       3 bool('apple')
#
# ValueError: invalid literal for int() with base 10: 'appple'

# %%
bool('apple')
# Out:
# True

# %% [markdown]
# - True: ON some thing is present
# - False: Off that is not present

# %%
bool('0')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
len('apple')
# Out:
# 5

# %%
len('0')
# Out:
# 1

# %%
len('   ')
# Out:
# 3

# %% [markdown]
# - for number 0 and 0.0 boolen conversion gives **False**
# - for strings empty boolen conversion gives **False**

# %%
float('10')
bool('10')
int('10')
# Out:
# 10

# %%
float('10')
# Out:
# 10.0

# %%
bool('10')
# Out:
# True

# %%
int('10')
# Out:
# 10

# %%
float('apple')
float('10')

# %% [markdown]
# **str object not callable**
#
# - python magic
# - either you need open notebook
# - or go to kernal and restart

# %%
float('10'),bool('10'),int('10')
# Out:
# (10.0, True, 10)

# %%
float('10'5')
bool('10'5')
int('10'5')
# Out:
#   Cell In[7], line 2
#     bool('10'5')
#               ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
** float is the boss**

float('10')
float('10.5')

int('10')
int('10.5')

# %% [markdown]
# **boolean to other data types**

# %%
print(int(True) ) 
print(float(True))
print(str(True) )
print(int(False) )
print(float(False))
print(str(False ))
# Out:
# 1
# 1.0
# True
# 0
# 0.0
# False

# %%
float(10)
str(10)
bool(10)
int(10.5)
str(10.5)
bool(10.5)
int(apple)
float(apple)
bool(apple)
int('10')
str('10')
bool('10')
float(True)
str(True)
bool(True)
