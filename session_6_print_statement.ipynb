# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10),print(20)
# Out:
# 10
# 20
# (None, None)

# %%
10,20
# Out:
# (10, 20)

# %%
print(a,b)
# Out:
# 10 20

# %%
print(30, 'naresh' , 'hyd')
# Out:
# 30 naresh hyd

# %%
num1=100
num2=200
add=num1+num2
# the addition of 100 and 200 is 300
print("the addition of 100 and 200 is 300")
print("the addion of num1 and  num2 is 200")
print("the additon of" ,num1, "and" ,num2, "is" ,add)
# Out:
# the addition of 100 and 200 is 300
# the addion of num1 and  num2 is 200
# the additon of 100 and 200 is 300

# %%
name="python"
age=10
city="hyd"
# name is python in 10 years old and form hyd
print("my name is pythonin 10 years old and came from hyd")
print("my name is name im age years old and came from city")
print("my name is", name, "im", age, "years old and came from", city)
# Out:
# my name is pythonin 10 years old and came from hyd
# my name is name im age years old and came from city
# my name is python im 10 years old and came from hyd

# %% [markdown]
# **format method**

# %%
name="python"
age=10
city="hyd"
print("my name is {} im {} years old and came from {}".format(name,age,city))
# Out:
# my name is python im 10 years old and came from hyd

# %%
num1=100
num2=200
add=num1+num2
print("the additon of 100 and age is 200")
print(" the additon of {} and {} is {}".format(num1,num2,add))
# Out:
# the additon of 100 and age is 200
#  the additon of 100 and 200 is 300

# %%
# wap take two numbers perform the
# subtraction
# multiplication
# division
# print the statements as follows

# the subtraction of 100 and 200 is -100
# the multiplication of 100 and 200 is 20000
# the division of 100 and 200 is 0.5

# %%
# wap take three number perform the avearage
# a,b,c 
# avg= (a+b+c)/3
# print the statement
# the avge of a,b,c is : avg

# %%
num1=100
num2=200
sub=num1-num2
print("the subtraction of num1 and num2 is sub")
print("the subtraction of {} and {} is {}".format(num1,num2,sub))
# Out:
# the subtraction of num1 and num2 is sub
# the subtraction of 100 and 200 is -100

# %%
num1=100
num2=200
mul=num1*num2
print("the multiplication of num1 and num2 is mul")
print("the multiplication of {} and {} is {}".format(num1,num2,mul))
# Out:
# the multiplication of num1 and num2 is mul
# the multiplication of 100 and 200 is 20000

# %%
num1=100
num2=200
div=num1/num2
print("the division of num1 and num2 is div")
print("the division of {} and {} is {}".format(num1,num2,div))
# Out:
# the division of num1 and num2 is div
# the division of 100 and 200 is 0.5

# %%
a=10
b=20
c=30
avg=(a+b+c)/3
print("the average of a,b,c is : avg")
print("the average of {},{},{} is : {}".format(a,b,c,avg))
# Out:
# the average of a,b,c is : avg
# the average of 10,20,30 is : 20.0

# %%
print("======================ADDITION===========================")
num1=1000
num2=200
add=num1+num2
# the addition of 100 and 200 is 300
print("the addition of 100 and 200 is 300")
print("the addition of {} and {} is {}".format(num1,num2,add))

print("========================SUBTRACTION===========================")

num1=100
num2=200
sub=num1-num2
print("the subtraction of num1 and num2 is sub")
print("the subtraction of {} and {} is {}".format(num1,num2,sub))


print("=======================MULTIPLICATION============================")


num1=100
num2=200
div=num1/num2
print("the division of num1 and num2 is div")
print("the division of {} and {} is {}".format(num1,num2,div))


print("========================DIVISION==========================")

a=10
b=20
c=30
avg=(a+b+c)/3
print("the average of a,b,c is : avg")
print("the average of {},{},{} is : {}".format(a,b,c,avg))
# Out:
# ======================ADDITION===========================
# the addition of 100 and 200 is 300
# the addition of 1000 and 200 is 1200
# ========================SUBTRACTION===========================
# the subtraction of num1 and num2 is sub
# the subtraction of 100 and 200 is -100
# =======================MULTIPLICATION============================
# the division of num1 and num2 is div
# the division of 100 and 200 is 0.5
# ========================DIVISION==========================
# the average of a,b,c is : avg
# the average of 10,20,30 is : 20.0

# %% [markdown]
# **f string formated string method**

# %%
num1=100
num2=200
add=num1+num2
print("the addition of 100 and 200 is 300")
print("the addition of {} and {} is {}".format(num1,num2,add))
print(f"the addition of {num1} and {num2} is {add}")
# Out:
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300
# the addition of 100 and 200 is 300

# %%
print("the addition of 100 and 200 is 300")
# Out:
# the addition of 100 and 200 is 300

# %%
a=11
b=20
c=30
avg1=(a+b+c)/3
print("the average of a,b,c is : avg")
print("the average of {},{},{}, is : {}".format(a,b,c,avg1))
print(f"the average of {a},{b},{c} is : {avg1}")
# Out:
# the average of a,b,c is : avg
# the average of 11,20,30, is : 20.333333333333332
# the average of 11,20,30 is : 20.333333333333332

# %%
print("======================ADDITION===========================")
num1=1000
num2=200
add=num1+num2
# the addition of 100 and 200 is 300
print("the addition of 100 and 200 is 300")
print("the addition of {} and {} is {}".format(num1,num2,add))
print(f"the addition of {num1} and {num2} is {add}")

print("========================SUBTRACTION===========================")

num1=100
num2=200
sub=num1-num2
print("the subtraction of num1 and num2 is sub")
print("the subtraction of {} and {} is {}".format(num1,num2,sub))
print(f"the subtraction of {num1} and {num2} is {sub}")

print("=======================MULTIPLICATION============================")


num1=100
num2=200
div=num1/num2
print("the division of num1 and num2 is div")
print("the division of {} and {} is {}".format(num1,num2,div))
print(f"the division of {num1} and {num2} is {div}")


print("========================DIVISION==========================")

a=10
b=20
c=30
avg=(a+b+c)/3
print("the average of a,b,c is : avg")
print("the average of {},{},{} is : {}".format(a,b,c,avg))
print(f"the average of {a},{b},{c} is : {avg}")
# Out:
# ======================ADDITION===========================
# the addition of 100 and 200 is 300
# the addition of 1000 and 200 is 1200
# the addition of 1000 and 200 is 1200
# ========================SUBTRACTION===========================
# the subtraction of num1 and num2 is sub
# the subtraction of 100 and 200 is -100
# the subtraction of 100 and 200 is -100
# =======================MULTIPLICATION============================
# the division of num1 and num2 is div
# the division of 100 and 200 is 0.5
# the division of 100 and 200 is 0.5
# ========================DIVISION==========================
# the average of a,b,c is : avg
# the average of 10,20,30 is : 20.0
# the average of 10,20,30 is : 20.0

# %%
a=11
b=20
c=30
avg=(a+b+c)/3
print(avg)
# Out:
# 20.333333333333332

# %% [markdown]
# **round**

# %%
# print()
# type()
# int()
# float()
# str()
# bool()
# round()

# CTRL+A 
# CTRL+/

# %%
print(round(10.77777))
print(round(10.77777,2))
print(round(10.77777,3))
# Out:
# 11
# 10.78
# 10.778

# %%
round(10.77777)  # 10.7 ===> 11
# 79.7  80
# Out:
# 11

# %%
round(10.77777,2)
# Out:
# 10.78

# %%
round(10.77777,3)
# Out:
# 10.778

# %%
round(8.899)
# Out:
# 9

# %%
a=11
b=20
c=30
avg=(a+b+c)/3
avg1=round(avg,2)
print(avg1)
print(round(avg,2))
# Out:
# 20.33
# 20.33

# %%
round(10.778,2)
# Out:
# 10.78

# %% [markdown]
# **i have multiple print statement but i want to show single line**

# %%
print(10)
print(20)
# Out:
# 10
# 20

# %%
(10, 20)
# Out:
# (10, 20)

# %%
print(10,20)
# Out:
# 10 20

# %% [markdown]
# **end**

# %%
print(10,end="====> ")
print(20)
# Out:
# 10====> 20

# %%
print(10,end=" ")
print(20,end=" ")
print(30)
# Out:
# 10 20 30

# %%
print("hello",end=' ')
print("how",end=' ')
print("are",end=' ')
print("you")
# Out:
# hello how are you

# %%
print('hello how are you')
# Out:
# hello how are you

# %% [markdown]
# **i have multiple value in a single print statement**
#
# **i want print them with seperation**

# %% [markdown]
# **sep**

# %%
print(10,20,30)
# 10====>20===>30
# Out:
# 10 20 30

# %%
print(10,20,30,sep='====>')
# Out:
# 10====>20====>30

# %% [markdown]
# - basic print statement
#
# - we learn format method
#
# - we learn f string method
#
# - we learn round
#
# - we learn end operator
#
# - we learn sep operator

# %%
# wap take the radidus of a circle calculate area of the circle
# var: radidus  var: pi=3.14
# formuale: pi*radius*radius
# print the answers using f string and format


var=int(input("enter radius:"))
pi=3.14
area=pi*var*var
print("area of circle of {} and {} is: {}".format(var,pi,area))
print(f"area of circle of {var}, and, {pi}, is: {area}")
# Out:
# enter radius: 6
# area of circle of 6 and 3.14 is: 113.03999999999999
# area of circle of 6, and, 3.14, is: 113.03999999999999

# %%
# wap take the breadth and height of a right angle triangle
# calculate the area
# var1: bredath  var2: height
# formuale : 0.5*breadth*heigh



var1=int(input("enter breadth:"))
var2=int(input("enter height:"))
area=0.5*var1*var2
print("area of tringle of breadth {} and height {} is: {}".format(var1,var2,area))
print(f"area of tringle of breadth {var1} and height {var2} is: {area}")
# Out:
# enter breadth: 6
# enter height: 8
# area of tringle of breadth 6 and height 8 is: 24.0
# area of tringle of breadth 6 and height 8 is: 24.0

# %%
# wap take the bill amount and tip amount
# calculate total bill
# var1: bill amount var2: tip amount
# formuale


var1=int(input("enter bill_amount:"))
var2=int(input("enter tip_amount:"))
total_bill=var1+var2
print("total bill by paying bill amount {} and tip amount {} is: {}".format(var1,var2,total_bill))
print(f"total bill by paying bill amount {var1} and tip amount {var2} is: {total_bill}")
# Out:
# enter bill_amount: 420
# enter tip_amount: 80
# total bill by paying bill amount 420 and tip amount 80 is: 500
# total bill by paying bill amount 420 and tip amount 80 is: 500

# %%
# wap take the length and breadth of a rectangle calculate area
# var1: length  var2: breadth
# formulae: length * breadth


var1=int(input("enter length:"))
var2=int(input("enter breadth:"))
area=var1*var2
print("area of rectringle of length {} and breadth {} is: {}".format(var1,var2,area))
print(f"area of rectringle of length {var1} and breadtht {var2} is: {area}")
# Out:
# enter length: 6
# enter breadth: 9
# area of rectringle of length 6 and breadth 9 is: 54
# area of rectringle of length 6 and breadtht 9 is: 54

# %% [markdown]
# **input**
#
# - in above we provided the value
#
# - input is the inbuilt function
#
# - using input by user can provide any value

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001B1EE7D10A0>>

# %% [markdown]
# **note:whenerver if we see bound method or function which is indicates we forgot the bracket**

# %%
input()
# Out:
#  10
# '10'

# %%
input()
# Out:
#  python
# 'python'

# %%
a=100
type(a)
# Out:
# int

# %%
b=input()
# Out:
#  10

# %%
b
# Out:
# '10'

# %%
n1=input()
n2=input()
n3=input()
# Out:
#  100
#  200
#  300

# %%
n1,n2,n3
# Out:
# ('100', '200', '300')

# %%
n1=input("enter the number1:")
n2=input("enter the number2:")
# Out:
# enter the number1: 100
# enter the number2: 200

# %%
n1=input("enter the number1:")
n2=input("enter the number2:")
n1+n2 #'500'+'600'='500600'
# Out:
# enter the number1: 500
# enter the number2: 600
# '500600'

# %% [markdown]
# **input values by default string type**

# %%
'100'+'200'
# Out:
# '100200'

# %%
str1='apple'
str2='is'
str3='fruite'
str1+str2+str3
# Out:
# 'appleisfruite'

# %%
str1=input("enter a string1")
str2=input("enter a string2")
str3=input("enter a string3")
str1+str2+str3
# Out:
# enter a string1 apple
# enter a string2 is
# enter a string3 fruite
# 'appleisfruite'

# %%
str1=input("enter a string1:")
str2=input("enter a string2:")
str3=input("enter a string3:")
str1+str2+str3
# Out:
# enter a string1:  apple
# enter a string2:  is
# enter a string3:  fruite
# ' apple is fruite'

# %%
n1=int(input("enter the number1:")) # n1=int('500')=500
n2=int(input("enter the number2:")) # n2=int('600')=600
n1+n2  # 500+600=1100
# Out:
# enter the number1: 500
# enter the number2: 600
# 1100

# %%
n1=input("enter the number1:")
n2=input("enter the number2:")
int(n1)+int(n2)
# Out:
# enter the number1: 500
# enter the number2: 600
# 1100

# %%
n1=float(input("enter the number1:")) 
n2=int(input("enter the number2:"))
n1+n2
# Out:
# enter the number1: 10.5
# enter the number2: 10
# 20.5

# %% [markdown]
# **eval**
# - eval means evaluate
# - it is related to math family
# - which means it works only number represent as strings
# - it will not works on english letters
# - eval will convert the repective data type which is user enter
# - if user enter 10 in quote it will convert into 10
# - if user enter 10.5 is quotes itwill conver into 10.5

# %%
int('10')
int('10.5') # error

# %%
float('10') # error
float('10.5')

# %%
eval('10'),eval('10.5')
# Out:
# (10, 10.5)

# %%
n1=eval(input("enter the number1:"))
n2=eval(input("enter the number2:"))
n1+n2
# Out:
# enter the number1: 10
# enter the number2: 10.5
# 20.5

# %%
# 1)wap ask the user enter 3 numbers n1,n2,n3 from ketboard
# calculate average

# 2)wap ask the user enter name age city
# print my name is python im 10 years old and came from hyd

# 3)wap ask the user to enter radidus of a circle calculate area of the circle
# var: radidus  var: pi=3.14
# formuale: pi*radius*radius
# print the answers using f string and format

# 4)wap ask the user enter breadth and height of a right angle triangle
# calculate the area
# var1: bredath  var2: height
# formuale : 0.5*breadth*heigh

# 5)wap ask the user the bill amount and tip amount
#   calculate total bill
#   var1: bill amount var2: tip amount
#   formuale

# 6)wap ask the user the bill amount and tip percentage
#    take tip percentage as 10
#   calculate total bill= bill amount+ bill amount*tip per/100
#   var1: bill amount var2: tip amount
#    formuale

# 7)wap ask the length and breadth of a rectangle calculate area
#   var1: length  var2: breadth
#   formulae: length * breadth

# 8) wap ask the user take the radius and calculate volume of sphere
#   formulae: pi*r**3(pi*r*r*r)

# 9) wap ask the user enter amount in dollars convert into rupees
#     1$=85rs

# 10)wap ask the user enter weight in kgs convert into pounds
#    1kg= 2.2pounds

# %%
# 1)wap ask the user enter 3 numbers n1,n2,n3 from ketboard
# calculate average

n1=float(input("enter the first number:"))
n2=float(input("enter the second number:"))
n3=float(input("enter the third number:"))
avg=(n1+n2+n3)/3
print("the average of the three numbers is:",avg)
# Out:
# enter the first number: 10
# enter the second number: 20
# enter the third number: 30
# the average of the three numbers is: 20.0

# %%
# 2)wap ask the user enter name age city
# print my name is python im 10 years old and came from hyd

name=input("enter name")
age=eval(input("enter age"))
city=input("enter city")
print(f"my name is {name} em {age} years old and came from {city}:")
# Out:
# enter name python
# enter age 10
# enter city hyd
# my name is python em 10 years old and came from hyd:

# %%
# 3)wap ask the user to enter radidus of a circle calculate area of the circle
# var: radidus  var: pi=3.14

var=eval(input("enter radius"))
pi= 3.14
area=pi*var*var
print(f"area of circle with radius {var} and pi {pi} is:{area}")
# Out:
# enter radius 10
# area of circle with radius 10 and pi 3.14 is:314.0

# %%
# 4)wap ask the user enter breadth and height of a right angle triangle
# calculate the area
# var1: bredath  var2: height
# formuale : 0.5*breadth*heigh

var1=int(input("enter breadth:"))
var2=int(input("enter height:"))
area=0.5*var1*var2
print(f"area of right angle tringle of breadth {var1} and height {var2} is: {area}")
# Out:
# enter breadth: 8
# enter height: 9
# area of right angle tringle of breadth 8 and height 9 is: 36.0

# %%
# 5)wap ask the user the bill amount and tip amount
#   calculate total bill
#   var1: bill amount var2: tip amount
#   formuale


var1=eval(input("enter bill amount"))
var2=eval(input("enter tip amount"))
total_bill=var1+var2
print(f" total bill paying by bill amount {var1} and tip amount {var2} is:{total_bill}")
# Out:
# enter bill amount 1000
# enter tip amount 100
#  total bill paying by bill amount 1000 and tip amount 100 is:1100

# %%
# 6)wap ask the user the bill amount and tip percentage
#    take tip percentage as 10
#   calculate total bill= bill amount+ bill amount*tip per/100
#   var1: bill amount var2: tip amount
#    formuale


var1=eval(input("enter bill amount"))
var2=eval(input("enter tip percent"))
Total_bill=var1+(var1*var2)/100
print(f"total bill after paying a bill amount {var1} and tip percent {var2} is:{Total_bill}")
# Out:
# enter bill amount 200
# enter tip percent 10
# total bill after paying a bill amount 200 and tip percent 10 is:220.0

# %%
# 7)wap ask the length and breadth of a rectangle calculate area
#   var1: length  var2: breadth
#   formulae: length * breadth


var1=eval(input("enter the length"))
var2=eval(input("enter the breadth"))
area=var1*var2
print(f"the area of rectangle of length{var1} and breadth {var2} is: {area}")
# Out:
# enter the length 10
# enter the breadth 7
# the area of rectangle of length10 and breadth 7 is: 70

# %%
# 8) wap ask the user take the radius and calculate volume of sphere
#   formulae: pi*r**3(pi*r*r*r)

radius
