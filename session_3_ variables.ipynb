# %% [markdown]
# # Variables

# %% [markdown]
# - Varible are used to store the data
# - The data can be change
# - These variable can be used to manupulate python code

# %%
number=100
# 100 is stored in a variable called as number
number
# Out:
# 100

# %%
NUMBER=200
NUMBER
# Out:
# 200

# %%
NUMber=300
NUMBER
# Out:
# 200

# %% [markdown]
# number, NUMBER, NUMber

# %%
(100, 200, 300)

# %%
number123=400
number123
# Out:
# 400

# %%
123number=500
123number
# Out:
#   Cell In[6], line 1
#     123number=500
#       ^
# SyntaxError: invalid decimal literal

# %%
# type first two letter enter tab

number123=400
number123
# Out:
# 400

# %% [markdown]
# **note**
# - variables generaly in black color
# - Green color shoud not be variables
# - numbers are suffix can work
# - numbers as prefix fail

# %%
number$=600
number$
# Out:
#   Cell In[1], line 1
#     number$=600
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# spl charecters are not allowed

# %%
number one=300
# Out:
#   Cell In[4], line 1
#     number one=300
#            ^
# SyntaxError: invalid syntax

# %%
number_one=600

# %%
number_one
# Out:
# 600

# %% [markdown]
# - underscore can use as variable

# %%
numberone

# %%
number

# %%
number=100
NUMBER=200
NUMber=300
123number=400
number123=500

# %%
number=100

# %%
numb
